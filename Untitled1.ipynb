# %%
import numpy as n

# %%
t = n.array([2,1,2.0])

# %%
type(t)
# Out:
# numpy.ndarray

# %%
l = [1,2,3,4]

# %%
[l**2 for i in l]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 [l**2 for i in l]
#
# Cell In[21], line 1, in <listcomp>(.0)
# ----> 1 [l**2 for i in l]
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
