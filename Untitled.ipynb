# %%
class Dog():
    var = [1,2,3,4]


d1 = Dog()
print(d1.var)
# Out:
# [1, 2, 3, 4]

# %%
d1.var[2] = 100

# %%
d1.var
# Out:
# [1, 2, 100, 4]

# %%
class School():
    def __init__(self,name):
        name = name

    def __str__(self):
        print(f'I am the super class: {name}')


class student(School):

    def __init__(self,name1, name2, age):
        name = name2
        age = age
        super().__init_(self,name1)

# %%
s = student("SB DAV", 'Akshansh', 15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s = student("SB DAV", 'Akshansh', 15)
#
# Cell In[5], line 14, in student.__init__(self, name1, name2, age)
#      12 name = name2
#      13 age = age
# ---> 14 super().__init_(self,name1)
#
# AttributeError: 'super' object has no attribute '_student__init_'
