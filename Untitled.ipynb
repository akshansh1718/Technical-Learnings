# %%
class Dog():
    var = [1,2,3,4]


d1 = Dog()
print(d1.var)
# Out:
# [1, 2, 3, 4]

# %%
d1.var[2] = 100

# %%
d1.var
# Out:
# [1, 2, 100, 4]

# %%
class School():
    def __init__(self,name):
        name = name

    def __str__(self):
        print(f'I am the super class: {name}')


class student(School):

    def __init__(self,name1, name2, age):
        name = name2
        age = age
        super().__init__(name1)

# %%
s = student("SB DAV", 'Akshansh', 15)

# %%
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(s)
#
# Cell In[8], line 6, in School.__str__(self)
#       5 def __str__(self):
# ----> 6     print(f'I am the super class: {name}')
#
# NameError: name 'name' is not defined
