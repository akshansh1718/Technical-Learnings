# %%
class Dog():
    var = [1,2,3,4]


d1 = Dog()
print(d1.var)
# Out:
# [1, 2, 3, 4]

# %%
d1.var[2] = 100

# %%
d1.var
# Out:
# [1, 2, 100, 4]

# %%
class School():
    area = 'Vasant Kunj'
    pin = 110044
    def __init__(self,name):
        self.name = name

    def __str__(self):
        return (f'I am the super class: {self.name2}')


class student(School):

    def __init__(self,name1, name2, age):
        self.name2 = name2
        self.age = age
        super().__init__(name1)

# %%
s = student("SB DAV", 'Akshansh', )

# %%
print(s)
# Out:
# I am the super class: Akshansh

# %%
print(s.__dict__)
# Out:
# {'name2': 'Akshansh', 'age': 15, 'name': 'SB DAV'}

# %%
s.area
# Out:
# 'Vasant Kunj'

# %%
s.pin
# Out:
# 110044

# %%
print(School.__dict__)
# Out:
# {'__module__': '__main__', 'area': 'Vasant Kunj', 'pin': 110044, '__init__': <function School.__init__ at 0x7ffee42f0d60>, '__str__': <function School.__str__ at 0x7ffee42f13a0>, '__dict__': <attribute '__dict__' of 'School' objects>, '__weakref__': <attribute '__weakref__' of 'School' objects>, '__doc__': None}
