# %%
import numpy as np

# %%
b = np.array([1,2,4,5])
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /tmp/ipykernel_994226/4201870139.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   b = np.array([1,2,4,5][1,2])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b = np.array([1,2,4,5][1,2])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
type(b)
# Out:
# numpy.ndarray

# %%
# %timeit b**2
# Out:
# array([ 1,  4, 16, 25])

# %%
l = range(100)

# %%
# %timeit [i**2 for i in l]
# Out:
# 11.7 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
